# %% [markdown]
# <img src="https://datasciencedegree.wisconsin.edu/wp-content/themes/data-gulp/images/logo.svg" width="300">

# %% [markdown]
# # Lesson 13 Activity -- Using ```tweepy``` for Data Mining

# %% [markdown]
# This is an introduction to data collection from <a href="http://www.twitter.com/">Twitter</a> using the [`tweepy`](http://www.tweepy.org/) package.

# %% [markdown]
# ---
#
# ## Getting set up -- things you do about once

# %% [markdown]
# ### Install Tweepy
#
# You must install the tweepy package from either Anaconda or the terminal on your computer before using it!

# %% [markdown]
# ### Make a twitter account
#
# You'll need to set up an app at <a href="https://apps.twitter.com/">apps.twitter.com</a>.

# %% [markdown]
# ### Save your credentials to an external file
#
# Make a plain text file on your computer called `twitter_credentials.py`, and put it anywhere but this directory.  I put mine in my home directory for my user.  It will look something like this:
#
#     con_key = 'your consumer key goes here'
#     con_secret = 'your consumer secret goes here'
#     acc_token = 'your access token goes here'
#     acc_secret = 'your access secret goes here'
#
# * Save your consumer key, consumer secret, access token, and access secret there.
# * Don't share these secrets with others!
# * It's also possible to generate access tokens and secrets from within an app, but now's not the right time for this.

# %% [markdown]
# ---
#
# ## Preliminaries to using tweepy -- things you do once per session
#
# You have to do these things about once per session.  If you close your notebook, or restart the kernel, then you have to do these things before you can again use the Tweepy interface to the Twitter API.

# %% [markdown]
# #### 1. Gain access to the Tweepy library
#
# As you would any other Python library, `import`.

# %%
import tweepy

# %% [markdown]
# #### 2. Load your credentials from the external file
#
# Invoke a python plain text source file located somewhere else on your computer.

# %%
# %run C:\Users\patse\tweeter.py
# this cell will evaluate silently 🙊, and not print anything.  
# This is desired, because a person with your keys can act as you on Twitter in literally every way 😟

# %% [markdown]
# 🔐 If you need to check whether the four variables, such as `con_key` have the correct value, insert a cell and print the value, then delete the cell.  Keep your credentials secret and safe!!!

# %% [markdown]
# #### 3. Make an `API` object
#
# The `tweepy.API` object handles construction of the Twitter API calls for you.  It's a convenience layer, but it's really dang convenient!

# %%
#Use tweepy.OAuthHandler to create an authentication using the given key and secret
auth = tweepy.OAuthHandler(consumer_key=con_key, consumer_secret=con_secret)
auth.set_access_token(acc_token, acc_secret)

#Connect to the Twitter API using the authentication
api = tweepy.API(auth)

# %% [markdown]
# ---
#
# ## Using the API
#
# Twitter has two versions of its API:
# * The [REST](https://en.wikipedia.org/wiki/Representational_state_transfer) [API](https://en.wikipedia.org/wiki/Application_programming_interface) allows you to _pull_ information from Twitter, or _push_ information back to Twitter.  For example,
#   💡 if I wanted to have a Python script that ran as a CRON job to automatically tweet for me under certain conditions, I would use the REST API.
# * The Streaming API allows us to monitor Twitter in real time, grabbing tweets as they are made.  For example,
#   💡 if I wanted to make a little device powered by a Raspberry Pi that showed interesting tweets in real time on a tiny screen by my desk, I would use the streaming API.

# %% [markdown]
# ### Method 1. The REST API
#
# The REST API allows you to _pull_ information from Twitter, or _push_ information back to Twitter.  We'll use the REST API to run a specific search.  You could also use the REST API to make automatic tweets on Twitter, or get information about specific users.

# %%
#Use the REST API for a static search
#Our example finds recent tweets using the hashtag #datascience

tweet_list = api.search(q='#%23ffxiv',until="2020-12-04",lang="en") #%23 is used to specify '#'

# %% [markdown]
# See [twitter's search documentation](https://dev.twitter.com/rest/public/search) for examples of query operators.  Pay attention to how to URL encode your query.  [This w3schools page](https://www.w3schools.com/tags/ref_urlencode.asp) has information on what `%23` and other encodings for URL's mean.

# %% [markdown]
# We retrieve a SearchResult object for each tweet, full of data such as the language, the identity of the poster, etc.

# %%
tweet_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-91c5ab94fd29> in <module>
# ----> 1 tweet_list[0]
#       2 api.rate_limit_status()
#
# IndexError: list index out of range

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '58077130-Pyqj4VDcYwBaa70QaArkgkK5zHgCVsJvYn3dE11SK'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1607383832},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1607383832},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1607383832},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1607383832}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1607383832}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   ':version': {'/:version/accounts/:account_id/curated_categories': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1607383832}},
#   'admin_users': {'/admin_users': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1607383832}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1607383832},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1607383832}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1607383832},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1607383832}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1607383832},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1607383832},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/:id': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1607383832},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/:source_user_id/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1607383832},
#    '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/users/by/username/:handle/tweets': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/users/by/username/:source_username/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/users/:id/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/users/by/username/:username': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/users/by/username/:username/followers': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/users/by/username/:username/following': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/users/by/username/:handle/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1607383832}},
#   'teams': {'/teams/authorize': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1607383832},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1607383832}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1607383832},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832}},
#   'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#     'remaining': 5,
#     'reset': 1607383832},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/labs/:version/users/:id/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1607383832},
#    '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1607383832},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1607383832},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/labs/:version/tweets/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/labs/:version/users/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/labs/:version/tweets/stream/compliance': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1607383832}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1607383832},
#    '/moments/create': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1607383832}},
#   'fleets': {'/fleets/:version/viewers': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/mutes/create': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/fleets/:version/track_events': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/fleetline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/fleet_threads': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/mutes/destroy': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/mutes/list': {'limit': 100,
#     'remaining': 100,
#     'reset': 1607383832},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832}},
#   'graphql&POST': {'/graphql&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1607383832},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1607383832},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1607383832},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1607383832},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1607383832},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1607383832},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1607383832},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1607383832},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#     'remaining': 150,
#     'reset': 1607383832}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1607383832},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1607383832}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'tweets': {'/tweets/search/recent': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832},
#    '/tweets/search/stream/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/tweets/sample/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/tweets/search/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1607383832},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1607383832},
#    '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1607383832},
#    '/tweets/search/stream/rules&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/tweets/search/stream/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/tweets/:id/hidden&PUT': {'limit': 50,
#     'remaining': 50,
#     'reset': 1607383832}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}},
#   'oauth': {'/oauth/revoke': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832},
#    '/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1607383832},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1607383832}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 179,
#     'reset': 1607383630}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1607383832},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1607383832},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1607383832}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1607383832}},
#   'graphql': {'/graphql': {'limit': 15,
#     'remaining': 15,
#     'reset': 1607383832}}}}

# %%
#We can use the dir command to view a list of the attributes of each tweet
dir(tweet_list[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
#Let's display the text of each tweet we found.
[tweet.retweet for tweet in tweet_list]
# Out:
# [<bound method Status.retweet of Status(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'created_at': 'Thu Dec 03 23:59:54 +0000 2020', 'id': 1334648587087572993, 'id_str': '1334648587087572993', 'text': 'RT @FF_XIV_EN: Oh my, what big eyes you have! 🐸👀\n\nWill luck be on your side this time?\nOr will Atomos go Y E E T\n\n5️⃣ days until #FFXIV Pat…', 'truncated': False, 'entities': {'hashtags': [{'text': 'FFXIV', 'indices': [129, 135]}], 'symbols': [], 'user_mentions': [{'screen_name': 'FF_XIV_EN', 'name': 'FINAL FANTASY XIV', 'id': 161223163, 'id_str': '161223163', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 141819693, 'id_str': '141819693', 'name': '巨大金魚🐟Pandaemonium🐼', 'screen_name': 'MegaTosakinto', 'location': '金魚すくい', 'description': 'すいすいぬε(・。・з)з', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 861, 'friends_count': 1231, 'listed_count': 28, 'created_at': 'Sun May 09 04:07:28 +0000 2010', 'favourites_count': 30252, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 56158, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/820572332427087872/jq_UIqfz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820572332427087872/jq_UIqfz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/141819693/1573369575', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Dec 03 16:00:18 +0000 2020', 'id': 1334527890898243585, 'id_str': '1334527890898243585', 'text': 'Oh my, what big eyes you have! 🐸👀\n\nWill luck be on your side this time?\nOr will Atomos go Y E E T\n\n5️⃣ days until… https://t.co/VqhtExjVN4', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/VqhtExjVN4', 'expanded_url': 'https://twitter.com/i/web/status/1334527890898243585', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 161223163, 'id_str': '161223163', 'name': 'FINAL FANTASY XIV', 'screen_name': 'FF_XIV_EN', 'location': 'Hydaelyn', 'description': 'Play the #FFXIV free trial up to level 60, then become the Warrior of Darkness in #Shadowbringers! Service updates: @FFXIV_NEWS_EN', 'url': 'https://t.co/lr6sjhCdu8', 'entities': {'url': {'urls': [{'url': 'https://t.co/lr6sjhCdu8', 'expanded_url': 'https://freetrial.finalfantasyxiv.com/', 'display_url': 'freetrial.finalfantasyxiv.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 302702, 'friends_count': 5, 'listed_count': 1309, ...
#  <bound method Status.retweet of Status(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'created_at': 'Thu Dec 03 23:59:53 +0000 2020', 'id': 1334648585288237058, 'id_str': '1334648585288237058', 'text': 'RT @AestMirra: Pictures taken around Lakeland.\n\nI like how how some of the places look a bit like painting when it gets foggy and it is rai…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AestMirra', 'name': 'Aest', 'id': 1134169219006959618, 'id_str': '1134169219006959618', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
...
#  <bound method Status.retweet of Status(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'created_at': 'Thu Dec 03 23:57:30 +0000 2020', 'id': 1334647984672419841, 'id_str': '1334647984672419841', 'text': 'Reminder that, in about an hour I’ll be streaming some more #CoffeeTalk over on #twitchtv. Another slow, chill stre… https://t.co/nKEN3ixVp5', 'truncated': True, 'entities': {'hashtags': [{'text': 'CoffeeTalk', 'indices': [60, 71]}, {'text': 'twitchtv', 'indices': [80, 89]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/nKEN3ixVp5', 'expanded_url': 'https://twitter.com/i/web/status/1334647984672419841', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1021940321276649472, 'id_str': '1021940321276649472', 'name': 'Belle 🔔 ENVtuber', 'screen_name': 'Belle_VTuberEN', 'location': 'Somewhere close to your heart~', 'description': 'Official Twitter for Belltower, an @twitch variety streamer and Vtuber who enjoys RTS and Indie Games. Trans. She/They. #VTuber #ENVTuber #VTuberEN', 'url': 'https://t.co/boq83ZPrj1', 'entities': {'url': {'urls': [{'url': 'https://t.co/boq83ZPrj1', 'expanded_url': 'https://www.twitch.tv/belletower', 'display_url': 'twitch.tv/belletower', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 55, 'friends_count': 151, 'listed_count': 3, 'created_at': 'Wed Jul 25 02:08:54 +0000 2018', 'favourites_count': 4030, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1147, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1326516516184068099/onAk7hAV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1326516516184068099/onAk7hAV_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 12, 3, 23, 57, 30), id=1334647984672419841, id_str='1334647984672419841', text='Reminder that, in about an hour I’ll be streaming some more #CoffeeTalk over on #twitchtv. Another slow, chill stre… https://t.co/nKEN3ixVp5', truncated=True, entities={'hashtags': [{'text': 'CoffeeTalk', 'indices': [60, 71]}, {'text': 'twitchtv', 'indices': [80, 89]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/nKEN3ixVp5', 'expanded_url': 'https://twitter.com/i/web/status/1334647984672419841', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'id': 1021940321276649472, 'id_str': '1021940321276649472', 'name': 'Belle 🔔 ENVtuber', 'screen_name': 'Belle_VTuberE ...
#  <bound method Status.retweet of Status(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'created_at': 'Thu Dec 03 23:57:27 +0000 2020', 'id': 1334647971812696069, 'id_str': '1334647971812696069', 'text': 'RT @AestMirra: Pictures taken around Lakeland.\n\nI like how how some of the places look a bit like painting when it gets foggy and it is rai…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AestMirra', 'name': 'Aest', 'id': 1134169219006959618, 'id_str': '1134169219006959618', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1089193319287148546, 'id_str': '1089193319287148546', 'name': 'Harui ハルイ🥪 graha fanart retweet machine', 'screen_name': 'starryskymochi', 'location': 'Crystarium', 'description': "DNC/WHM🌼| catboy obliterator |'the rains have ceased, and we have been graced with another beautiful day. but you are not here to see it'| (pfp by @koimoinoi)", 'url': 'https://t.co/4XgLYH2ZxT', 'entities': {'url': {'urls': [{'url': 'https://t.co/4XgLYH2ZxT', 'expanded_url': 'https://supernova-ffxiv.tumblr.com/post/626295400438038528', 'display_url': 'supernova-ffxiv.tumblr.com/post/626295400…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 95, 'listed_count': 0, 'created_at': 'Sat Jan 26 16:08:18 +0000 2019', 'favourites_count': 10301, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 826, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1334232684663595015/sV_5HISD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334232684663595015/sV_5HISD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1089193319287148546/1606942632', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Dec 03 12:17:00 +0000 2020', 'id': 1334471695906844672, 'id_str': '1334471695906844672', 'text': 'Pictures taken around Lakeland.\n\nI like how how some of the places look a bit like painting when it gets foggy and… https://t.co/8uUCTrXvEP', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8uUCTrXvEP', 'expanded_url': 'https://twitter.com/i/web/status/1334471695906844672', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 
 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1334602333641031682, 'source_status_id_str': '1334602333641031682', 'source_user_id': 736174714213662720, 'source_user_id_str': '736174714213662720'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 188977490, 'id_str': '188977490', 'name': '🍂Arcane🍁', 'screen_name': 'ArcaneStardust', 'location': 'United States', 'description': '🦄🔞Arc/Arcane/Ashley, 31 years old, she/her. In FFXIV hell. Posts NSFW. RT heavy. Not spoiler-free. Header by @laevxtein', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 84, 'friends_count': 1655, 'listed_count': 2, 'created_at': 'Fri Sep 10 01:44:51 +0000 2010', 'favourites_count': 80513, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 49179, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1291836781168594944/ZVmdvSR1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291836781168594944/ZVmdvSR1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/188977490/1589289602', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': F ...
#  <bound method Status.retweet of Status(_api=<tweepy.api.API object at 0x000001F9ADF30F10>, _json={'created_at': 'Thu Dec 03 23:56:37 +0000 2020', 'id': 1334647759304011776, 'id_str': '1334647759304011776', 'text': 'RT @AestMirra: Pictures taken around Lakeland.\n\nI like how how some of the places look a bit like painting when it gets foggy and it is rai…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AestMirra', 'name': 'Aest', 'id': 1134169219006959618, 'id_str': '1134169219006959618', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2549225342, 'id_str': '2549225342', 'name': 'RaichuSama', 'screen_name': 'Raichu_Sama', 'location': 'Shawnee, KS', 'description': '🔞+ likes | Cactuar Raichu Sama |\n💝@Typhlosion_Sama is my Hubby💝\n💖@wonderfvl is my buddy forever💖\n💞@SpeaksAkira @LTF_Sancy @Sempraternal are my besties.💞', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 79, 'friends_count': 535, 'listed_count': 0, 'created_at': 'Fri Jun 06 04:25:59 +0000 2014', 'favourites_count': 29316, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10983, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1275003894846959616/u3x15F4W_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275003894846959616/u3x15F4W_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2549225342/1592820698', 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Dec 03 12:17:00 +0000 2020', 'id': 1334471695906844672, 'id_str': '1334471695906844672', 'text': 'Pictures taken around Lakeland.\n\nI like how how some of the places look a bit like painting when it gets foggy and… https://t.co/8uUCTrXvEP', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8uUCTrXvEP', 'expanded_url': 'https://twitter.com/i/web/status/1334471695906844672', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1134169219006959618, 'id_str': '1134169219006959618', 'name': 'Aest', 'screen_name': 'AestMirra', 'location': '', 'description': 'Mostly pictures of my adventures in Final Fantasy 14!  Screenshots and other material are Copyrighted (C) 2010-2020 SQUARE ENIX CO., LTD. All Rights Reserved.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1714, 'friends_count': 525, 'listed_count': 15, 'created_at': 'Thu May 30 18:46:28 +0000 2019', 'favourites_count' ...

# %% [markdown]
# By default, the REST API returns 15 tweets.  We can get up to 100 by using the argument "count".

# %%
tweet_list = api.search(q='#%23datascience', count = 100)
len(tweet_list)

# %% [markdown]
# If we want more than 100 tweets, we can use a *while* loop.  The max_id argument lets us collect tweets that are older than a particular tweet index (in this case, the oldest tweet we've seen so far).
#
# The `try/except/else` structure lets us fail gracefully in case the API search returns an error (e.g., if we run up against Twitter's rate limits).

# %%
num_needed = 2000
tweet_list = []
last_id = -1 # id of last tweet seen
while len(tweet_list) < num_needed:
    try:
        new_tweets = api.search(q = '#%23ffxiv',until="2020-12-07",count = 100,max_id = str(last_id - 1))
    except tweepy.TweepError as e:
        print("Error", e)
        break
    else:
        if not new_tweets:
            print("Could not find any more tweets!")
            break
        tweet_list.extend(new_tweets)
        last_id = new_tweets[-1].id

len(tweet_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e8d6abbe13ca> in <module>
#       4 while len(tweet_list) < num_needed:
#       5     try:
# ----> 6         new_tweets = api.search(q = '#%23ffxiv',until="2020-12-07",count = 100,max_id = str(last_id - 1)).filter(retweet_count > 0)
#       7     except tweepy.TweepError as e:
#       8         print("Error", e)
#
# AttributeError: 'SearchResults' object has no attribute 'filter'

# %% [markdown]
# Note that the free REST API restricts the number of tweets you can retrieve, and the dates: you may not be able to retrieve tweets that are more than a week old.  Pay attention to this restriction as you approach your final project topic!

# %% [markdown]
# ## Method 2. The Streaming API
#
# The Streaming API allows us to monitor Twitter in real time, grabbing tweets as they are made.

# %% [markdown]
# The ```tweepy``` package includes a class called ```StreamListener``` which monitors Twitter for us.  However, by default StreamListener does nothing with the tweets it collects.
#
# In this demonstration, we'll modify ```StreamListener``` to make a class that prints each tweet we're interested in to the screen.  Later, you may wish to create your own class which saves information from tweets to a file.

# %%
#We create a subclass of tweepy.StreamListener to add a response to on_status

class PrintingStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        
    #disconnect the stream if we receive an error message indicating we are overloading Twitter
    
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

# %% [markdown]
# Once we have created our subclass, we can set up our own Twitter stream.

# %%
#We create and authenticate an instance of our new ```PrintingStreamListener``` class

my_stream_listener = PrintingStreamListener()
my_stream = tweepy.Stream(auth = api.auth, listener=my_stream_listener)

# %% [markdown]
# We'll use the ```track``` command to look for tweets with a specific keyword.  You can read more about constructing searches with ```track``` in the <a href="https://dev.twitter.com/streaming/overview/request-parameters#track">Twitter streaming API documentation</a>.

# %%
# Now, we're ready to start streaming!  We'll look for recent tweets which use the word "data".
# You can pause the display of tweets by interrupting the Python kernel (use the menu bar at the top)

stream_tweets = my_stream.filter(track=['ffxiv'])
# Out:
# #FFXIV Now Urianger will fill Thancred's ammunitions...im dead #PS4share https://t.co/ci9F2sV22K
# RT @aetherflows: FFXIV: Patch 5.4 - Futures Rewritten (Eden's Promise) https://t.co/OWoqWCAf5w
# Great stream last night, much respect to all who were there in both viewing and Spirit.
#
# Ffxiv raids tonight!
# it's amazing how ffxiv's warrior of light has sorta captured the true essence of what being a hero is without ever… https://t.co/Co4VOUDJfI
# RT @prinxeling: ** NEW MERCH **
#
# Hello! I've updated my shop with a bunch of new stickers! They will be up until supplies last!
#
# Get yours…
# RT @KipuneV: Crafting!!😸🍳 #FFXIV #ffxivmemes https://t.co/4cfC7hkkhe
# Hey Beans! Guess what! 5.4 has dropped and tonight I will be starting the MSQ @ 6 pm est! Get your tissues ready (I… https://t.co/3pNMmJq5tf
# RT @PhoenixFF14: 忍者の穴N装備と新式5禁断を比較
# サブステ1当たりの上昇係数は俺ツールさん（https://t.co/Pl7WTKBWLF）を参照
# 覚えやすいのは下記事項
# ①N装備DH+クリで新式がSS強ステならN装備
# ②新式が意思+SSでN装備がDH+クリo…
# Bonus early stream as I check out the new 5.4 update for FFXIV. https://t.co/PTqaWO4LWP #Twitch #Twitchtv… https://t.co/zfr5nWeEJE
# RT @coeurlclaw: ffxiv players will wait patiently for maintenance to end, but only for 24 hours. after that, they will begin their assault
# RT @Kathryn__Lynn: https://t.co/qkP7iChj6t
#
# Good morning everyone! Super excited about 5.4! We’re jumping right in this morning at 10am pt!…
# 日記「【なご散歩：568歩目】：パッチ5.4が来たので自由探索をしてみた【1発SS撮り】」 | FINAL FANTASY XIV, The Lodestone https://t.co/cfVF1TGxCl
# #FF14 #FFXIV #ロスガル
# ~rolls around waiting for my pay so that I can resub and play ffxiv~ https://t.co/uz1ngwfD61
# RT @redbeersake: Reposting this piece in celebration of 5.4 releasing!!!
# May Eden's Promise treat us well, and may it treat them well ;w;!…
# RT @winterleigh_art: Dance, dance, until the nightmares fade away
#
# Commission for Rosen Hue
# This is one of the most complicated artworks I'…
# RT @GreyFoxVinzin: We got Vans in #FFXIV babeh~!
#
# (These look so out of place... it's freaking hilarious) https://t.co/cql8gtjd9O
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-1009a436c9bd> in <module>
#       2 # You can pause the display of tweets by interrupting the Python kernel (use the menu bar at the top)
#       3
# ----> 4 my_stream.filter(track=['ffxiv'])
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Even if you pause the display of tweets, your stream is still connected to Twitter!
# To disconnect (for example, if you want to change which words you are searching for), 
# use the disconnect() function.

my_stream.disconnect()

# %% [markdown]
# ---
#
# ## Suggestions for skills to learn
#
# * Collect 1000 tweets matching a search, or all available in the current time window, whichever comes first.  That 1000 was arbitrary
# * Extract just the fields you are most interested in from a search, and create a Pandas data frame
# * Follow the graph of followers from a specific Twitter user

# %% [markdown]
# ---
#
# ## Useful resources and links
#
# * [the structure of the Status object of Tweepy](https://gist.github.com/dev-techmoe/ef676cdd03ac47ac503e856282077bf2)
# * [Tweet Data Dictionary](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object)
# * [Standard Operators](https://developer.twitter.com/en/docs/tweets/search/guides/standard-operators) -- premium operators cost money.
# * [Twitter operators by product](https://developer.twitter.com/en/docs/tweets/rules-and-filtering/overview/operators-by-product) -- by product they mean *paid access level*
# * [How to use Twitter’s Search REST API most effectively](https://www.karambelkar.info/2015/01/how-to-use-twitters-search-rest-api-most-effectively./)
# * [Collecting Tweets with Tweepy](http://www.dealingdata.net/2016/07/23/PoGo-Series-Tweepy/)
